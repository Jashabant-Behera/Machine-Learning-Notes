# %% [markdown]
# <img src="https://r2cdn.perplexity.ai/pplx-full-logo-primary-dark%402x.png" style="height:64px;margin-right:32px"/>
#
# # 📊 Complete Statistics Reference for ML/DL
#
# **All Concepts with Definitions, Formulas, Code Examples, and Practical Use Cases**
#
# ***
#
# ## Table of Contents
#
# 1. [What is Statistics?](#what-is-statistics)
# 2. [Types of Statistics](#types-of-statistics)
# 3. [Types of Data](#types-of-data)
# 4. [Descriptive Statistics](#descriptive-statistics)
# 5. [Measures of Central Tendency](#measures-of-central-tendency)
# 6. [Measures of Dispersion](#measures-of-dispersion)
# 7. [Univariate Analysis Graphs](#univariate-analysis-graphs)
# 8. [Bivariate Analysis Graphs](#bivariate-analysis-graphs)
#
# ***
